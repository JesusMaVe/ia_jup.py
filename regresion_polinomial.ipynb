# %%
import numpy as np
import pandas as pd 
import math 
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

from sklearn.metrics import mean_squared_error
from math import sqrt

# %%
x = np.arange(0, 30)
y = [3, 4, 5, 7, 10, 8, 9, 10, 10, 23, 27, 44, 50, 63, 67, 60, 62, 70, 75, 88, 81, 87, 95, 100, 108, 135, 151, 168, 169, 179]

plt.figure(figsize=(10, 6))
plt.scatter(x, y)
plt.show()
